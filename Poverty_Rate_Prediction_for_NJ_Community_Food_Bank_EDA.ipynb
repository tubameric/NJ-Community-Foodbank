# %% [markdown]
# <a href="https://colab.research.google.com/github/tubameric/NJ-Community-Foodbank/blob/main/Poverty_Rate_Prediction_for_NJ_Community_Food_Bank_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assigning the dataset URL
url = 'https://raw.githubusercontent.com/tubameric/PortfolioProjects/main/NJ%20Community%20Food%20Bank%20-%20Poverty%20Data.csv'

# Displaying the url
url
# Out:
# 'https://raw.githubusercontent.com/tubameric/PortfolioProjects/main/NJ%20Community%20Food%20Bank%20-%20Poverty%20Data.csv'

# %%
# Importing pandas for data processing
import pandas as pd

# Importing the data into a variable
data = pd.read_csv(url)

# Display the data
data
# Out:
#       row_id                                         area__rucc  \
# 0          0  Nonmetro - Completely rural or less than 2,500...
# 1          2  Nonmetro - Urban population of 2,500 to 19,999...
# 2          4  Nonmetro - Completely rural or less than 2,500...
# 3          5  Nonmetro - Urban population of 2,500 to 19,999...
# 4          8  Metro - Counties in metro areas of 1 million p...
# ...      ...                                                ...
# 3193    6270  Metro - Counties in metro areas of 250,000 to ...
# 3194    6273  Nonmetro - Completely rural or less than 2,500...
# 3195    6275  Metro - Counties in metro areas of 1 million p...
# 3196    6276  Nonmetro - Completely rural or less than 2,500...
# 3197    6277  Nonmetro - Completely rural or less than 2,500...
#
#                                   area__urban_influence  \
# 0                Noncore adjacent to a large metro area
# 1           Micropolitan adjacent to a large metro area
# ...

# %%
# Displaying the dataset shape
data.shape
# Out:
# (3198, 35)

# %%
# Displaying the dataset info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 35 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   row_id                                            3198 non-null   int64
#  1   area__rucc                                        3198 non-null   object
#  2   area__urban_influence                             3198 non-null   object
#  3   econ__economic_typology                           3198 non-null   object
#  4   econ__pct_civilian_labor                          3198 non-null   float64
#  5   econ__pct_unemployment                            3198 non-null   float64
#  6   econ__pct_uninsured_adults                        3196 non-null   float64
#  7   econ__pct_uninsured_children                      3196 non-null   float64
#  8   demo__pct_female                                  3196 non-null   float64
# ...

# %%
# Displaying descriptive stats of the dataset
data.describe()
# Out:
#             row_id  econ__pct_civilian_labor  econ__pct_unemployment  \
# count  3198.000000               3198.000000              3198.00000
# mean   3156.692620                  0.467071                 0.05961
# std    1823.959278                  0.074541                 0.02285
# min       0.000000                  0.217000                 0.00800
# 25%    1561.750000                  0.420000                 0.04400
# 50%    3198.500000                  0.467000                 0.05700
# 75%    4723.750000                  0.514000                 0.07100
# max    6277.000000                  1.000000                 0.24000
#
#        econ__pct_uninsured_adults  econ__pct_uninsured_children  \
# count                 3196.000000                   3196.000000
# mean                     0.217534                      0.085920
# std                      0.067372                      0.040005
# min                      0.046000                      0.009000
# ...

# %%
# Installing dataprep package for data profiling
# !pip install dataprep

# %%
# Importing the dataprep package
from dataprep.eda import create_report

# Generating a data profiling report using dataprep's create_report
create_report(data).save()
# Out:
# Computing series-sum-agg-342cc5230aba21f2a398989b52671931:   4%|▍         | 329/7666 [00:00<00:12, 592.76it/s]      /usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# ERROR:bokeh.core.validation.check:E-1019 (DUPLICATE_FACTORS): FactorRange must specify a unique list of categorical factors for an axis: duplicate factors found: 'demo__pct_adu...oma'
# Report has been saved to /content/report.html!

# %%
# Displaying the data columns
data.columns
# Out:
# Index(['row_id', 'area__rucc', 'area__urban_influence',
#        'econ__economic_typology', 'econ__pct_civilian_labor',
#        'econ__pct_unemployment', 'econ__pct_uninsured_adults',
#        'econ__pct_uninsured_children', 'demo__pct_female',
#        'demo__pct_below_18_years_of_age', 'demo__pct_aged_65_years_and_older',
#        'demo__pct_hispanic', 'demo__pct_non_hispanic_african_american',
#        'demo__pct_non_hispanic_white',
#        'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
#        'demo__pct_adults_less_than_a_high_school_diploma',
#        'demo__pct_adults_with_high_school_diploma',
#        'demo__pct_adults_with_some_college',
#        'demo__pct_adults_bachelors_or_higher', 'demo__birth_rate_per_1k',
#        'demo__death_rate_per_1k', 'health__pct_adult_obesity',
#        'health__pct_adult_smoking', 'health__pct_diabetes',
#        'health__pct_low_birthweight', 'health__pct_excessive_drinking',
# ...

# %%
# Selecting variables with atleast 80% available data
data80 = data[['area__rucc', 'area__urban_influence',
       'econ__economic_typology', 'econ__pct_civilian_labor',
       'econ__pct_unemployment', 'econ__pct_uninsured_adults',
       'econ__pct_uninsured_children', 'demo__pct_female',
       'demo__pct_below_18_years_of_age', 'demo__pct_aged_65_years_and_older',
       'demo__pct_hispanic', 'demo__pct_non_hispanic_african_american',
       'demo__pct_non_hispanic_white',
       'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
       'demo__pct_adults_less_than_a_high_school_diploma',
       'demo__pct_adults_with_high_school_diploma',
       'demo__pct_adults_with_some_college',
       'demo__pct_adults_bachelors_or_higher', 'demo__birth_rate_per_1k',
       'demo__death_rate_per_1k', 'health__pct_adult_obesity',
       'health__pct_adult_smoking', 'health__pct_diabetes',
       'health__pct_low_birthweight',
       'health__pct_physical_inacticity',
       'health__air_pollution_particulate_matter',
       'health__motor_vehicle_crash_deaths_per_100k',
       'health__pop_per_dentist', 'health__pop_per_primary_care_physician',
       'yr', 'poverty_rate']]

# Displaying the data80 columns
data80.columns
# Out:
# Index(['area__rucc', 'area__urban_influence', 'econ__economic_typology',
#        'econ__pct_civilian_labor', 'econ__pct_unemployment',
#        'econ__pct_uninsured_adults', 'econ__pct_uninsured_children',
#        'demo__pct_female', 'demo__pct_below_18_years_of_age',
#        'demo__pct_aged_65_years_and_older', 'demo__pct_hispanic',
#        'demo__pct_non_hispanic_african_american',
#        'demo__pct_non_hispanic_white',
#        'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
#        'demo__pct_adults_less_than_a_high_school_diploma',
#        'demo__pct_adults_with_high_school_diploma',
#        'demo__pct_adults_with_some_college',
#        'demo__pct_adults_bachelors_or_higher', 'demo__birth_rate_per_1k',
#        'demo__death_rate_per_1k', 'health__pct_adult_obesity',
#        'health__pct_adult_smoking', 'health__pct_diabetes',
#        'health__pct_low_birthweight', 'health__pct_physical_inacticity',
# ...

# %%
# Setting the predictor variables
predictors = data80[['area__rucc', 'area__urban_influence',
       'econ__economic_typology', 'econ__pct_civilian_labor',
       'econ__pct_unemployment', 'econ__pct_uninsured_adults',
       'econ__pct_uninsured_children', 'demo__pct_female',
       'demo__pct_below_18_years_of_age', 'demo__pct_aged_65_years_and_older',
       'demo__pct_hispanic', 'demo__pct_non_hispanic_african_american',
       'demo__pct_non_hispanic_white',
       'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
       'demo__pct_adults_less_than_a_high_school_diploma',
       'demo__pct_adults_with_high_school_diploma',
       'demo__pct_adults_with_some_college',
       'demo__pct_adults_bachelors_or_higher', 'demo__birth_rate_per_1k',
       'demo__death_rate_per_1k', 'health__pct_adult_obesity',
       'health__pct_adult_smoking', 'health__pct_diabetes',
       'health__pct_low_birthweight',
       'health__pct_physical_inacticity',
       'health__air_pollution_particulate_matter',
       'health__motor_vehicle_crash_deaths_per_100k',
       'health__pop_per_dentist', 'health__pop_per_primary_care_physician',
       'yr', 'poverty_rate']]

# Displaying predictor columns
predictors.columns
# Out:
# Index(['area__rucc', 'area__urban_influence', 'econ__economic_typology',
#        'econ__pct_civilian_labor', 'econ__pct_unemployment',
#        'econ__pct_uninsured_adults', 'econ__pct_uninsured_children',
#        'demo__pct_female', 'demo__pct_below_18_years_of_age',
#        'demo__pct_aged_65_years_and_older', 'demo__pct_hispanic',
#        'demo__pct_non_hispanic_african_american',
#        'demo__pct_non_hispanic_white',
#        'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
#        'demo__pct_adults_less_than_a_high_school_diploma',
#        'demo__pct_adults_with_high_school_diploma',
#        'demo__pct_adults_with_some_college',
#        'demo__pct_adults_bachelors_or_higher', 'demo__birth_rate_per_1k',
#        'demo__death_rate_per_1k', 'health__pct_adult_obesity',
#        'health__pct_adult_smoking', 'health__pct_diabetes',
#        'health__pct_low_birthweight', 'health__pct_physical_inacticity',
# ...

# %%
# Displaying correlations
predictors.corr()
# Out:
# <ipython-input-14-57484c537422>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   predictors.corr()
#                                                   econ__pct_civilian_labor  \
# econ__pct_civilian_labor                                          1.000000
# econ__pct_unemployment                                           -0.612938
# econ__pct_uninsured_adults                                       -0.409326
# econ__pct_uninsured_children                                     -0.032743
# demo__pct_female                                                  0.110623
# demo__pct_below_18_years_of_age                                  -0.011560
# demo__pct_aged_65_years_and_older                                 0.001866
# demo__pct_hispanic                                                0.008591
# ...

# %%
# Installing sweetviz package for EDA
# !pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 57.0 MB/s eta 0:00:00
# ...

# %%
# Importing the sv package
import sweetviz as sv

# %%
# Generating EDA report using sv package
sv_report=sv.analyze(predictors)

# Converting the report to html format
sv_report.show_html("Poverty Rate Prediction for NJ Community Food Bank EDA Report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Poverty Rate Prediction for NJ Community Food Bank EDA Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
